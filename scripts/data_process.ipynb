# %% [markdown]
# ## 1- Filter CVD Death Patients
# Remove all the NON-CVD death patients. Here we take in input the original dataset and output the original dataset with only CVD Death patients:
# - Input: data.csv
# - Output: data_cvd.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# %matplotlib inline

# %%
# load data
df = pd.read_csv("./data/data/data.csv", index_col=0, decimal='.')
df_date = pd.read_csv("./data/data/extra_date.csv", index_col=0)
df = pd.merge(df, df_date, left_index=True, right_index=True)
df.convert_dtypes()
df["Follow Up Data"] = pd.to_datetime(df["Follow Up Data"], format="%m/%d/%Y")
df["Data prelievo (1)"] = pd.to_datetime(df["Data prelievo (1)"], format="%m/%d/%Y")

# %%
# remove ONLY and ALL the deaths patients NON-CVD (Fatal MI or Sudden death, UnKnown, Accident, Suicide)
total = df[df["Total mortality"]==1].index
cvd_idx = df[df["CVD Death"]==1].index
noncvd_idx = set(total) - set(cvd_idx)

# print(f"Total deaths: {len(total)}")
# print(f"Death CVD: {len(cvd_idx)}")
# print(f"Death Non-CVD: {len(noncvd_idx)}")

df_cvd = df.drop(noncvd_idx)
print(f"\nTotal patients: {len(df)}")
print(f"Total patients (after removal of Death Non-CVD): {len(df_cvd)}")
df.info()

assert len(noncvd_idx) == len(total) - len(cvd_idx)
assert len(df.columns) == len(df_cvd.columns)
# df_cvd.to_csv("data/data/data_cvd.csv")
# Out:
# Total patients: 5820
# Total patients (after removal of Death Non-CVD): 4762
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5820 entries, 395 to 1193
# Data columns (total 93 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Age (1)                                     5820 non-null   int64
#  1   Gender (Male = 1)                           5820 non-null   int64
#  2   Angina                                      5820 non-null   int64
#  3   Previous CABG                               5820 non-null   int64
#  4   Previous PCI                                5820 non-null   int64
#  5   Previous
# Myocardial Infarction             5820 non-null   int64
#  6   Acute
# Myocardial Infarction                5820 non-null   int64
#  7   Angiography                                 5820 non-null   int64
#  8   Vessels                                     3562 non-null   float64
#  9   CAD                                         5820 non-null   int64
#  10  Smoke
# History of smoke                      5820 non-null   int64
#  11  Diabetes
# History of diabetes                5820 non-null   int64
#  12  Hypertension
# History of hypertension        5820 non-null   int64
#  13  Dyslipidemia
# Hystory of dyslipidemia        5820 non-null   int64
#  14  Family history of CAD                       5820 non-null   int64
#  15  Obesity
# History of obesity                  5820 non-null   int64
#  16  Documented resting
# or exertional ischemia  5820 non-null   int64
#  17  Post-ischemic Dilated
# Cardiomyopathy        5820 non-null   int64
#  18  Primary Dilated
# Cardiomyopathy              5820 non-null   int64
#  19  Atrial Fibrillation                         5820 non-null   int64
#  20  Paroxysmal atrial fibrillation              5820 non-null   int64
#  21  B-Blockers                                  5820 non-null   int64
#  22  Amiodarone                                  5820 non-null   int64
#  23  Calcium channel blockers                    5820 non-null   int64
#  24  Diuretics                                   5820 non-null   int64
#  25  Antiplatelet                                5820 non-null   int64
#  26  Nitrates                                    5820 non-null   int64
#  27  ACE-inhibitors                              5820 non-null   int64
#  28  Ipolipemizzanti                             5820 non-null   int64
#  29  Antidiabetici                               5820 non-null   int64
#  30  Total mortality                             5820 non-null   int64
#  31  Non CVD Death                               5809 non-null   float64
#  32  CVD Death                                   5820 non-null   int64
#  33  Fatal MI or Sudden death                    5820 non-null   int64
#  34  UnKnown                                     5820 non-null   int64
#  35  Accident                                    5820 non-null   int64
#  36  Suicide                                     5820 non-null   int64
#  37  Cabg                                        5820 non-null   int64
#  38  Non fatal AMI                               5820 non-null   int64
#  39  Pci                                         5820 non-null   int64
#  40  Total cholesterol                           5820 non-null   int64
#  41  HDL                                         5820 non-null   int64
#  42  LDL                                         5820 non-null   float64
#  43  Triglycerides                               5820 non-null   int64
#  44  Glycemia                                    5813 non-null   float64
#  45  TSH                                         5820 non-null   float64
#  46  fT3                                         5820 non-null   float64
#  47  fT4                                         5820 non-null   float64
#  48  Euthyroid                                   5820 non-null   float64
#  49  Subclinical primary hypothyroidism (SCH)    5820 non-null   float64
#  50  Subclinical primary hyperthyroidism
# (SCT)   5820 non-null   float64
#  51  Low T3                                      5820 non-null   float64
#  52  Ipotiroidismo                               5820 non-null   float64
#  53  Ipertiroidismo                              5820 non-null   float64
#  54  Controllo                                   5820 non-null   float64
#  55  Patologia TIROIDE                           113 non-null    object
#  56  Normal                                      5820 non-null   int64
#  57  SindromeX                                   5820 non-null   int64
#  58  AMI                                         5820 non-null   int64
#  59  PMI                                         5820 non-null   int64
#  60  Aritmie                                     5820 non-null   int64
#  61  MIN                                         5820 non-null   int64
#  62  MIO                                         5820 non-null   int64
#  63  Miocardite                                  5820 non-null   int64
#  64  Pericardite                                 5820 non-null   int64
#  65  Endocardite                                 5820 non-null   int64
#  66  Valvulopatie                                5820 non-null   int64
#  67  MalattiaVasoAorta                           5820 non-null   int64
#  68  Ipertensione                                5820 non-null   int64
#  69  CardiopatiaCongenita                        5820 non-null   int64
#  70  EmboliaPolmonare                            5820 non-null   int64
#  71  EPA                                         5820 non-null   int64
#  72  HR                                          5791 non-null   float64
#  73  Weight                                      5820 non-null   int64
#  74  Height                                      5820 non-null   int64
#  75  BMI                                         5820 non-null   float64
#  76  Diastolic blood pressure                    5820 non-null   int64
#  77  Systolic blood pressure                     5820 non-null   int64
#  78  WmsiBas                                     5820 non-null   float64
#  79  DimSettoIV                                  5820 non-null   int64
#  80  DimParPost                                  5820 non-null   int64
#  81  fe                                          5820 non-null   int64
#  82  vsx                                         5820 non-null   int64
#  83  Follow Up Data                              5820 non-null   datetime64[ns]
#  84  Data of death                               1469 non-null   object
#  85  Cause of death                              1469 non-null   object
#  86  Cardiac cause of death                      5809 non-null   float64
#  87  Collected by                                1469 non-null   object
#  88  CABG                                        635 non-null    object
#  89  Non Fatal AMI (Follow-Up)                   204 non-null    object
#  90  PCI                                         1013 non-null   object
#  91  Ictus                                       73 non-null     object
#  92  Data prelievo (1)                           5820 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(18), int64(65), object(8)
# memory usage: 4.3+ MB

# %% [markdown]
# ## 2- Clean Irrelevant Features
# From the only CVD death patients, we remove all the irrelevant features for the classification task. We also create a target feature.
# - Input: data_cvd.csv
# - Output: data_cvd_clean.csv

# %%
df_cvd = pd.read_csv("./data/data/data_cvd.csv", index_col=0, decimal='.')
df_cvd["Follow Up Data"] = pd.to_datetime(df_cvd["Follow Up Data"])
df_cvd["Data prelievo (1)"] = pd.to_datetime(df_cvd["Data prelievo (1)"])

# %%
# compute difference between dates: follow up and admission
df_diff = (df_cvd["Follow Up Data"] - df_cvd["Data prelievo (1)"]).map(lambda x: x.days // 365)
df_diff.value_counts().sort_index().plot(kind='bar')
plt.title("Distribution of the difference between Follow up - Recovery")
plt.xlabel("Years")
plt.ylabel("Number of patients")
# Out:
# Text(0, 0.5, 'Number of patients')

# %%
# complete vessels feature, if CAD == 0 then Vessels can be set to 0, otherwise we don't know the Vessels
for i in df_cvd.index:
    if (pd.isna(df_cvd["Vessels"][i]) and df_cvd["CAD"][i]==0):
        df_cvd.loc[i, "Vessels"] = 0
    elif (pd.isna(df_cvd["Vessels"][i]) and df_cvd["CAD"][i]==1):
        df_cvd.loc[i, "Vessels"] = -1

# clean features remove follow up features
df_feat = df_cvd.copy()
df_feat = pd.concat([df_feat.iloc[:, :30], df_feat.iloc[:, 40:]], axis=1)
df_feat = df_feat.drop(columns=["Patologia TIROIDE ", "Controllo", "Weight", "Height",
                                "AMI", "CABG ", "Cardiac cause of death", "Cause of death",
                                "Collected by", "Data of death", "Data prelievo (1)", "Follow Up Data",
                                "Ictus", "Non Fatal AMI (Follow-Up)", "PCI", "PMI"])

# create and add target feature
years = 7
survive = (df_diff < years) & df_cvd["CVD Death"]
survive = (survive + 1) % 2
df_feat[f"Survive{years}Y"] = survive

print("Total patient: \t", len(df_feat))
print("Survived: \t", df_feat[f"Survive{years}Y"].sum(), "\t", df_feat[f"Survive{years}Y"].sum()/len(df_feat))
print("Dead: \t\t", len(df_feat)-df_feat[f"Survive{years}Y"].sum(), "\t", (len(df_feat)-df_feat[f"Survive{years}Y"].sum())/len(df_feat))
df_feat = df_feat.convert_dtypes()
df_feat.info()

# df_feat.to_csv("data/data/data_cvd_clean.csv")
# Out:
# Total patient: 	 4762
# Survived: 	 4406 	 0.9252414951700966
# Dead: 		 356 	 0.0747585048299034
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4762 entries, 8986 to 1193
# Data columns (total 68 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Age (1)                                     4762 non-null   Int64
#  1   Gender (Male = 1)                           4762 non-null   Int64
#  2   Angina                                      4762 non-null   Int64
#  3   Previous CABG                               4762 non-null   Int64
#  4   Previous PCI                                4762 non-null   Int64
#  5   Previous
# Myocardial Infarction             4762 non-null   Int64
#  6   Acute
# Myocardial Infarction                4762 non-null   Int64
#  7   Angiography                                 4762 non-null   Int64
#  8   Vessels                                     4762 non-null   Float64
#  9   CAD                                         4762 non-null   Int64
#  10  Smoke
# History of smoke                      4762 non-null   Int64
#  11  Diabetes
# History of diabetes                4762 non-null   Int64
#  12  Hypertension
# History of hypertension        4762 non-null   Int64
#  13  Dyslipidemia
# Hystory of dyslipidemia        4762 non-null   Int64
#  14  Family history of CAD                       4762 non-null   Int64
#  15  Obesity
# History of obesity                  4762 non-null   Int64
#  16  Documented resting
# or exertional ischemia  4762 non-null   Int64
#  17  Post-ischemic Dilated
# Cardiomyopathy        4762 non-null   Int64
#  18  Primary Dilated
# Cardiomyopathy              4762 non-null   Int64
#  19  Atrial Fibrillation                         4762 non-null   Int64
#  20  Paroxysmal atrial fibrillation              4762 non-null   Int64
#  21  B-Blockers                                  4762 non-null   Int64
#  22  Amiodarone                                  4762 non-null   Int64
#  23  Calcium channel blockers                    4762 non-null   Int64
#  24  Diuretics                                   4762 non-null   Int64
#  25  Antiplatelet                                4762 non-null   Int64
#  26  Nitrates                                    4762 non-null   Int64
#  27  ACE-inhibitors                              4762 non-null   Int64
#  28  Ipolipemizzanti                             4762 non-null   Int64
#  29  Antidiabetici                               4762 non-null   Int64
#  30  Total cholesterol                           4762 non-null   Int64
#  31  HDL                                         4762 non-null   Int64
#  32  LDL                                         4762 non-null   Float64
#  33  Triglycerides                               4762 non-null   Int64
#  34  Glycemia                                    4755 non-null   Int64
#  35  TSH                                         4762 non-null   Float64
#  36  fT3                                         4762 non-null   Float64
#  37  fT4                                         4762 non-null   Float64
#  38  Euthyroid                                   4762 non-null   Int64
#  39  Subclinical primary hypothyroidism (SCH)    4762 non-null   Int64
#  40  Subclinical primary hyperthyroidism
# (SCT)   4762 non-null   Int64
#  41  Low T3                                      4762 non-null   Int64
#  42  Ipotiroidismo                               4762 non-null   Int64
#  43  Ipertiroidismo                              4762 non-null   Int64
#  44  Normal                                      4762 non-null   Int64
#  45  SindromeX                                   4762 non-null   Int64
#  46  Aritmie                                     4762 non-null   Int64
#  47  MIN                                         4762 non-null   Int64
#  48  MIO                                         4762 non-null   Int64
#  49  Miocardite                                  4762 non-null   Int64
#  50  Pericardite                                 4762 non-null   Int64
#  51  Endocardite                                 4762 non-null   Int64
#  52  Valvulopatie                                4762 non-null   Int64
#  53  MalattiaVasoAorta                           4762 non-null   Int64
#  54  Ipertensione                                4762 non-null   Int64
#  55  CardiopatiaCongenita                        4762 non-null   Int64
#  56  EmboliaPolmonare                            4762 non-null   Int64
#  57  EPA                                         4762 non-null   Int64
#  58  HR                                          4739 non-null   Int64
#  59  BMI                                         4762 non-null   Float64
#  60  Diastolic blood pressure                    4762 non-null   Int64
#  61  Systolic blood pressure                     4762 non-null   Int64
#  62  WmsiBas                                     4762 non-null   Float64
#  63  DimSettoIV                                  4762 non-null   Int64
#  64  DimParPost                                  4762 non-null   Int64
#  65  fe                                          4762 non-null   Int64
#  66  vsx                                         4762 non-null   Int64
#  67  Survive7Y                                   4762 non-null   Int64
# dtypes: Float64(7), Int64(61)
# memory usage: 2.9 MB

# %% [markdown]
# ## 3- Add Extra Subset Information
# From the CVD-cleaned dataset, we add further information about subsets. These subsets are used for classifying specific group of patients
# - Input: data_cvd_clean.csv
# - Output: data_cvd_clean_subset.csv

# %%
df_subset = pd.read_csv("./data/data/data_cvd_clean.csv", index_col=0, decimal='.')
df_sub = pd.read_csv("./data/data/extra_subset.csv", index_col=0, decimal='.')

# %%
# number of patients per category
df_sub["Classificazione pazienti"].value_counts().sort_index().plot(kind='bar')
plt.title("#Patients per category")
plt.xlabel("Patients")
plt.ylabel("Categories")
# Out:
# Text(0, 0.5, 'Categories')

# %%
# correct the old dataset with the new data, which has some corrections
df_subset = df_subset.sort_index(ascending=True)
df_sub_clean = df_sub.drop(list(set(df_sub.index) - set(df_subset.index)))
assert (df_subset.index == df_sub_clean.index).all
# sum(df_sub_clean["Previous \nMyocardial Infarction - PMI"] == df["Previous \nMyocardial Infarction"])

df_subset["Previous \nMyocardial Infarction"] = df_sub_clean["Previous \nMyocardial Infarction - PMI"]
df_subset["Angiography"] = df_sub_clean["Angiography"]
df_subset["Documented resting \nor exertional ischemia"] = df_sub_clean["Documented resting \nor exertional ischemia"]
df_subset["Post-ischemic Dilated\nCardiomyopathy"] = df_sub_clean["Post-ischemic Dilated\nCardiomyopathy"]
df_subset["Primary Dilated\nCardiomyopathy"] = df_sub_clean["Primary Dilated\nCardiomyopathy"]

# %%
# feature engineering
df_subset = df_subset.copy()
df_subset["MIO"] = df_subset["MIN"] | df_subset["MIO"]
df_subset.rename(columns={"MIO": "MIO/MIN"}, inplace=True)
df_subset = df_subset.drop(columns=["MIN", "Angiography"])

# fix all the NA patients
# 1. remove Suriveve7Y = 1 and NA
# 2. fill other NA's HR = average(HR of Survive7Y = 0) = 76
df_na = df_subset[df_subset.isna().any(axis=1)]
df_subset = df_subset.drop(df_na[df_na["Survive7Y"] == 1].index)
df_subset.loc[df_na[df_na["Survive7Y"] == 0].index, "HR"] = 76

years = 7
print("Total patient: \t", len(df_subset))
print("Survived: \t", df_subset[f"Survive{years}Y"].sum(), "\t", df_subset[f"Survive{years}Y"].sum()/len(df_subset))
print("Dead: \t\t", len(df_subset)-df_subset[f"Survive{years}Y"].sum(), "\t", (len(df_subset)-df_subset[f"Survive{years}Y"].sum())/len(df_subset))
df_subset.info()

# df_subset.to_csv("data/data/data_cvd_clean_subset.csv")
# Out:
# Total patient: 	 4734
# Survived: 	 4378 	 0.9247993240388678
# Dead: 		 356 	 0.07520067596113224
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4734 entries, 3 to 9085
# Data columns (total 66 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Age (1)                                     4734 non-null   int64
#  1   Gender (Male = 1)                           4734 non-null   int64
#  2   Angina                                      4734 non-null   int64
#  3   Previous CABG                               4734 non-null   int64
#  4   Previous PCI                                4734 non-null   int64
#  5   Previous
# Myocardial Infarction             4734 non-null   int64
#  6   Acute
# Myocardial Infarction                4734 non-null   int64
#  7   Vessels                                     4734 non-null   float64
#  8   CAD                                         4734 non-null   int64
#  9   Smoke
# History of smoke                      4734 non-null   int64
#  10  Diabetes
# History of diabetes                4734 non-null   int64
#  11  Hypertension
# History of hypertension        4734 non-null   int64
#  12  Dyslipidemia
# Hystory of dyslipidemia        4734 non-null   int64
#  13  Family history of CAD                       4734 non-null   int64
#  14  Obesity
# History of obesity                  4734 non-null   int64
#  15  Documented resting
# or exertional ischemia  4734 non-null   int64
#  16  Post-ischemic Dilated
# Cardiomyopathy        4734 non-null   int64
#  17  Primary Dilated
# Cardiomyopathy              4734 non-null   int64
#  18  Atrial Fibrillation                         4734 non-null   int64
#  19  Paroxysmal atrial fibrillation              4734 non-null   int64
#  20  B-Blockers                                  4734 non-null   int64
#  21  Amiodarone                                  4734 non-null   int64
#  22  Calcium channel blockers                    4734 non-null   int64
#  23  Diuretics                                   4734 non-null   int64
#  24  Antiplatelet                                4734 non-null   int64
#  25  Nitrates                                    4734 non-null   int64
#  26  ACE-inhibitors                              4734 non-null   int64
#  27  Ipolipemizzanti                             4734 non-null   int64
#  28  Antidiabetici                               4734 non-null   int64
#  29  Total cholesterol                           4734 non-null   int64
#  30  HDL                                         4734 non-null   int64
#  31  LDL                                         4734 non-null   float64
#  32  Triglycerides                               4734 non-null   int64
#  33  Glycemia                                    4734 non-null   float64
#  34  TSH                                         4734 non-null   float64
#  35  fT3                                         4734 non-null   float64
#  36  fT4                                         4734 non-null   float64
#  37  Euthyroid                                   4734 non-null   int64
#  38  Subclinical primary hypothyroidism (SCH)    4734 non-null   int64
#  39  Subclinical primary hyperthyroidism
# (SCT)   4734 non-null   int64
#  40  Low T3                                      4734 non-null   int64
#  41  Ipotiroidismo                               4734 non-null   int64
#  42  Ipertiroidismo                              4734 non-null   int64
#  43  Normal                                      4734 non-null   int64
#  44  SindromeX                                   4734 non-null   int64
#  45  Aritmie                                     4734 non-null   int64
#  46  MIO/MIN                                     4734 non-null   int64
#  47  Miocardite                                  4734 non-null   int64
#  48  Pericardite                                 4734 non-null   int64
#  49  Endocardite                                 4734 non-null   int64
#  50  Valvulopatie                                4734 non-null   int64
#  51  MalattiaVasoAorta                           4734 non-null   int64
#  52  Ipertensione                                4734 non-null   int64
#  53  CardiopatiaCongenita                        4734 non-null   int64
#  54  EmboliaPolmonare                            4734 non-null   int64
#  55  EPA                                         4734 non-null   int64
#  56  HR                                          4734 non-null   float64
#  57  BMI                                         4734 non-null   float64
#  58  Diastolic blood pressure                    4734 non-null   int64
#  59  Systolic blood pressure                     4734 non-null   int64
#  60  WmsiBas                                     4734 non-null   float64
#  61  DimSettoIV                                  4734 non-null   int64
#  62  DimParPost                                  4734 non-null   int64
#  63  fe                                          4734 non-null   int64
#  64  vsx                                         4734 non-null   int64
#  65  Survive7Y                                   4734 non-null   int64
# dtypes: float64(9), int64(57)
# memory usage: 2.5 MB

# %% [markdown]
# ## 4- Remove the medicines
# Remove all the medicines from the dataset
# - Input: data_cvd_clean_subset.csv
# - Output: data_cvd_clean_subset_nomeds.csv

# %%
df_subset = pd.read_csv("./data/data/data_cvd_clean_subset.csv", index_col=0, decimal='.')
df_subset.info()

# %%
df_subset_nomeds = df_subset.drop(columns=[
                                "B-Blockers",
                                "Amiodarone",
                                "Calcium channel blockers",
                                "Diuretics",
                                "Antiplatelet",
                                "Nitrates",
                                "ACE-inhibitors",
                                "Ipolipemizzanti",
                                "Antidiabetici",
                            ])

# df_subset_nomeds.info()
# df_subset_nomeds.to_csv("data/data/data_cvd_clean_subset_nomeds.csv")
df_subset_nomeds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4734 entries, 3 to 9085
# Data columns (total 57 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Age (1)                                     4734 non-null   int64
#  1   Gender (Male = 1)                           4734 non-null   int64
#  2   Angina                                      4734 non-null   int64
#  3   Previous CABG                               4734 non-null   int64
#  4   Previous PCI                                4734 non-null   int64
#  5   Previous
# Myocardial Infarction             4734 non-null   int64
#  6   Acute
# Myocardial Infarction                4734 non-null   int64
#  7   Vessels                                     4734 non-null   float64
#  8   CAD                                         4734 non-null   int64
#  9   Smoke
# History of smoke                      4734 non-null   int64
#  10  Diabetes
# History of diabetes                4734 non-null   int64
#  11  Hypertension
# History of hypertension        4734 non-null   int64
#  12  Dyslipidemia
# Hystory of dyslipidemia        4734 non-null   int64
#  13  Family history of CAD                       4734 non-null   int64
#  14  Obesity
# History of obesity                  4734 non-null   int64
#  15  Documented resting
# or exertional ischemia  4734 non-null   int64
#  16  Post-ischemic Dilated
# Cardiomyopathy        4734 non-null   int64
#  17  Primary Dilated
# Cardiomyopathy              4734 non-null   int64
#  18  Atrial Fibrillation                         4734 non-null   int64
#  19  Paroxysmal atrial fibrillation              4734 non-null   int64
#  20  Total cholesterol                           4734 non-null   int64
#  21  HDL                                         4734 non-null   int64
#  22  LDL                                         4734 non-null   float64
#  23  Triglycerides                               4734 non-null   int64
#  24  Glycemia                                    4734 non-null   float64
#  25  TSH                                         4734 non-null   float64
#  26  fT3                                         4734 non-null   float64
#  27  fT4                                         4734 non-null   float64
#  28  Euthyroid                                   4734 non-null   int64
#  29  Subclinical primary hypothyroidism (SCH)    4734 non-null   int64
#  30  Subclinical primary hyperthyroidism
# (SCT)   4734 non-null   int64
#  31  Low T3                                      4734 non-null   int64
#  32  Ipotiroidismo                               4734 non-null   int64
#  33  Ipertiroidismo                              4734 non-null   int64
#  34  Normal                                      4734 non-null   int64
#  35  SindromeX                                   4734 non-null   int64
#  36  Aritmie                                     4734 non-null   int64
#  37  MIO/MIN                                     4734 non-null   int64
#  38  Miocardite                                  4734 non-null   int64
#  39  Pericardite                                 4734 non-null   int64
#  40  Endocardite                                 4734 non-null   int64
#  41  Valvulopatie                                4734 non-null   int64
#  42  MalattiaVasoAorta                           4734 non-null   int64
#  43  Ipertensione                                4734 non-null   int64
#  44  CardiopatiaCongenita                        4734 non-null   int64
#  45  EmboliaPolmonare                            4734 non-null   int64
#  46  EPA                                         4734 non-null   int64
#  47  HR                                          4734 non-null   float64
#  48  BMI                                         4734 non-null   float64
#  49  Diastolic blood pressure                    4734 non-null   int64
#  50  Systolic blood pressure                     4734 non-null   int64
#  51  WmsiBas                                     4734 non-null   float64
#  52  DimSettoIV                                  4734 non-null   int64
#  53  DimParPost                                  4734 non-null   int64
#  54  fe                                          4734 non-null   int64
#  55  vsx                                         4734 non-null   int64
#  56  Survive7Y                                   4734 non-null   int64
# dtypes: float64(9), int64(48)
# memory usage: 2.1 MB

# %% [markdown]
# ## 5- Remove many redundant features
# Remove many redundant features
# - Input: data_cvd_clean_subset_nomeds.csv
# - Output: data_cvd_clean_subset_nomeds_noredundant.csv

# %%
df_subset = pd.read_csv("./data/data/data_cvd_clean_subset_nomeds.csv", index_col=0, decimal='.')
df_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4734 entries, 3 to 9085
# Data columns (total 57 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Age (1)                                     4734 non-null   int64
#  1   Gender (Male = 1)                           4734 non-null   int64
#  2   Angina                                      4734 non-null   int64
#  3   Previous CABG                               4734 non-null   int64
#  4   Previous PCI                                4734 non-null   int64
#  5   Previous
# Myocardial Infarction             4734 non-null   int64
#  6   Acute
# Myocardial Infarction                4734 non-null   int64
#  7   Vessels                                     4734 non-null   float64
#  8   CAD                                         4734 non-null   int64
#  9   Smoke
# History of smoke                      4734 non-null   int64
#  10  Diabetes
# History of diabetes                4734 non-null   int64
#  11  Hypertension
# History of hypertension        4734 non-null   int64
#  12  Dyslipidemia
# Hystory of dyslipidemia        4734 non-null   int64
#  13  Family history of CAD                       4734 non-null   int64
#  14  Obesity
# History of obesity                  4734 non-null   int64
#  15  Documented resting
# or exertional ischemia  4734 non-null   int64
#  16  Post-ischemic Dilated
# Cardiomyopathy        4734 non-null   int64
#  17  Primary Dilated
# Cardiomyopathy              4734 non-null   int64
#  18  Atrial Fibrillation                         4734 non-null   int64
#  19  Paroxysmal atrial fibrillation              4734 non-null   int64
#  20  Total cholesterol                           4734 non-null   int64
#  21  HDL                                         4734 non-null   int64
#  22  LDL                                         4734 non-null   float64
#  23  Triglycerides                               4734 non-null   int64
#  24  Glycemia                                    4734 non-null   float64
#  25  TSH                                         4734 non-null   float64
#  26  fT3                                         4734 non-null   float64
#  27  fT4                                         4734 non-null   float64
#  28  Euthyroid                                   4734 non-null   int64
#  29  Subclinical primary hypothyroidism (SCH)    4734 non-null   int64
#  30  Subclinical primary hyperthyroidism
# (SCT)   4734 non-null   int64
#  31  Low T3                                      4734 non-null   int64
#  32  Ipotiroidismo                               4734 non-null   int64
#  33  Ipertiroidismo                              4734 non-null   int64
#  34  Normal                                      4734 non-null   int64
#  35  SindromeX                                   4734 non-null   int64
#  36  Aritmie                                     4734 non-null   int64
#  37  MIO/MIN                                     4734 non-null   int64
#  38  Miocardite                                  4734 non-null   int64
#  39  Pericardite                                 4734 non-null   int64
#  40  Endocardite                                 4734 non-null   int64
#  41  Valvulopatie                                4734 non-null   int64
#  42  MalattiaVasoAorta                           4734 non-null   int64
#  43  Ipertensione                                4734 non-null   int64
#  44  CardiopatiaCongenita                        4734 non-null   int64
#  45  EmboliaPolmonare                            4734 non-null   int64
#  46  EPA                                         4734 non-null   int64
#  47  HR                                          4734 non-null   float64
#  48  BMI                                         4734 non-null   float64
#  49  Diastolic blood pressure                    4734 non-null   int64
#  50  Systolic blood pressure                     4734 non-null   int64
#  51  WmsiBas                                     4734 non-null   float64
#  52  DimSettoIV                                  4734 non-null   int64
#  53  DimParPost                                  4734 non-null   int64
#  54  fe                                          4734 non-null   int64
#  55  vsx                                         4734 non-null   int64
#  56  Survive7Y                                   4734 non-null   int64
# dtypes: float64(9), int64(48)
# memory usage: 2.1 MB

# %%
print(df_subset_nomeds["Documented resting \nor exertional ischemia"].sum())
print(df_subset_nomeds["Angina"].sum())
print()

print(df_subset_nomeds["Paroxysmal atrial fibrillation"].sum())
print(df_subset_nomeds["Atrial Fibrillation"].sum())
print()

print(df_subset_nomeds["Normal"].sum())
print(df_subset_nomeds["SindromeX"].sum())
print(df_subset_nomeds["MIO/MIN"].sum())
print(df_subset_nomeds["Miocardite"].sum())
print(df_subset_nomeds["Pericardite"].sum())
print(df_subset_nomeds["Endocardite"].sum())
print(df_subset_nomeds["CardiopatiaCongenita"].sum())
print()

print(df_subset_nomeds["Ipertensione"].sum())
print(df_subset_nomeds["Hypertension\nHistory of hypertension"].sum())
# Out:
# 2006
# 2513
#
# 198
# 865
#
# 76
# 8
# 54
# 22
# 54
# 13
# 72
#
# 2618
# 2891

# %%
df_subset_noredundant = df_subset_nomeds.drop(columns=[
                                "Documented resting \nor exertional ischemia",
                                "Paroxysmal atrial fibrillation",
                                "Normal",
                                "SindromeX",
                                "MIO/MIN",
                                "Miocardite"
                                "Pericardite"
                                "Endocardite"
                                "CardiopatiaCongenita"
                                "Ipertensione"
                            ])

# %% [markdown]
# ## Extra utilities
# Create and save the subset datagroups

# %%
# dataset train, valid, test split
def split_and_save(df, path, verbose=True):
    from sklearn.model_selection import train_test_split
    df_train, df_test = train_test_split(df, test_size=0.2, stratify=df.iloc[:,-1])
    df_train, df_valid = train_test_split(df_train, test_size=0.2, stratify=df_train.iloc[:,-1])

    df_train.to_csv(f"{path}train.csv")
    df_valid.to_csv(f"{path}valid.csv")
    df_test.to_csv(f"{path}test.csv")

    if verbose: 
        print("Train: \t", len(df_train))
        print("Valid: \t", len(df_valid))
        print("Test: \t", len(df_test))

# %%
# number of patients for each subgroup
# - 6 Coronary Artery Disease
# - 5 Cardiomiopatia Dilatative Primitiva
# - 4 Miocardite, Pericardite, Endocardite... 
# - 3 Ipertensione, Aritmie

# divide into subgroups and save the datasets
df_6 = df_subset_nomeds[df_sub_clean["Classificazione pazienti"] == 6]
df_5 = df_subset_nomeds[df_sub_clean["Classificazione pazienti"] == 5]
df_4 = df_subset_nomeds[df_sub_clean["Classificazione pazienti"] == 4]
df_3 = df_subset_nomeds[df_sub_clean["Classificazione pazienti"] == 3]

# split_and_save(df_6, "data/data/7y_subset/6CAD/")
# split_and_save(df_5, "data/data/7y_subset/5CDP/")
# split_and_save(df_4, "data/data/7y_subset/4Cardite_Altro/")
# split_and_save(df_3, "data/data/7y_subset/3Ipertensione_Aritmie/")
# split_and_save(df_subset, "data/data/7y_subset/complete/")
# Out:
# <ipython-input-50-a3016289637e>:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_6 = df_subset_nomeds[df_sub_clean["Classificazione pazienti"] == 6]
# <ipython-input-50-a3016289637e>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_5 = df_subset_nomeds[df_sub_clean["Classificazione pazienti"] == 5]
# <ipython-input-50-a3016289637e>:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_4 = df_subset_nomeds[df_sub_clean["Classificazione pazienti"] == 4]
# <ipython-input-50-a3016289637e>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_3 = df_subset_nomeds[df_sub_clean["Classificazione pazienti"] == 3]

# %%
# save the CAD subset removing the medicines features
df_train = pd.read_csv("data/data/7y_subset/6CAD/train.csv", index_col=0, decimal='.')
df_valid = pd.read_csv("data/data/7y_subset/6CAD/valid.csv", index_col=0, decimal='.')
df_test = pd.read_csv("data/data/7y_subset/6CAD/test.csv", index_col=0, decimal='.')
assert len(set(df_train.columns) - set(df_6.columns)) == 9

df_train_nomeds = df_6.loc[df_train.index, :]
df_valid_nomeds = df_6.loc[df_valid.index, :]
df_test_nomeds = df_6.loc[df_test.index, :]
assert len(df_train_nomeds) == len(df_train)

# df_train_nomeds.to_csv("data/data/7y_subset_nomeds/6CAD/train.csv")
# df_valid_nomeds.to_csv("data/data/7y_subset_nomeds/6CAD/valid.csv")
# df_test_nomeds.to_csv("data/data/7y_subset_nomeds/6CAD/test.csv")

# %%
from collections import Counter
print(Counter(df_6["Survive7Y"]))
print(Counter(df_5["Survive7Y"]))
print(Counter(df_4["Survive7Y"]))
print(Counter(df_3["Survive7Y"]))
# Out:
# Counter({1: 2406, 0: 213})
# Counter({1: 318, 0: 41})
# Counter({1: 460, 0: 66})
# Counter({1: 1009, 0: 35})

# %%
print(Counter(df_train_nomeds["Survive7Y"]))
print(Counter(df_valid_nomeds["Survive7Y"]))
print(Counter(df_test_nomeds["Survive7Y"]))
# Out:
# Counter({1: 1606, 0: 142})
# Counter({1: 402, 0: 36})
# Counter({1: 398, 0: 35})

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(35,30))
sns.heatmap(df_feat.corr(), annot=True)
# fig.savefig("feat.pdf")
